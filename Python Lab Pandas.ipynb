# %%
import pandas as pd

# %%
data = [[60,65,35],
        [90,34,80],
        [95,98,59],
        [60,75,60]]

# %%
df = pd.DataFrame(data, index = ["A" , "B" , "C" , "D"] , columns = ["Course_A","Course_B","Course_C"])

# %%
df
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# B        90        34        80
# C        95        98        59
# D        60        75        60

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
housing_df = pd.read_csv(r"C:\Users\huwen\Downloads\housing.csv")

# %%
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf pandas cheat sheet

# %%
housing_df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_df.tail(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
housing_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_df.loc[4,:] # loc using name iloc using index
# Out:
# longitude              -122.25
# latitude                 37.85
# housing_median_age        52.0
# total_rooms             1627.0
# total_bedrooms           280.0
# population               565.0
# households               259.0
# median_income           3.8462
# median_house_value    342200.0
# ocean_proximity       NEAR BAY
# Name: 4, dtype: object

# %%
df.iloc[1:,1:]
# Out:
#    Course_B  Course_C
# B        34        80
# C        98        59
# D        75        60

# %%
df.loc[["C","D"],["Course_B","Course_C"]]
# Out:
#    Course_B  Course_C
# C        98        59
# D        75        60

# %%
# series
Course_A = df.loc[:,"Course_A"]

# %%
Course_A.describe()
# Out:
# count     4.000000
# mean     76.250000
# std      18.874586
# min      60.000000
# 25%      60.000000
# 50%      75.000000
# 75%      91.250000
# max      95.000000
# Name: Course_A, dtype: float64

# %%
Course_A.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
Course_A.sum()
# Out:
# 305

# %%
Course_A.mean()
# Out:
# 76.25

# %%
Course_A.apply(lambda number: number **2)
# Out:
# A    3600
# B    8100
# C    9025
# D    3600
# Name: Course_A, dtype: int64

# %%
df.loc[:,"Course_A"].apply(lambda number: number **2)
# Out:
# A    3600
# B    8100
# C    9025
# D    3600
# Name: Course_A, dtype: int64

# %%
# filtering dataframe with boolean indexes
df["Course_A"]
# Out:
# A    60
# B    90
# C    95
# D    60
# Name: Course_A, dtype: int64

# %%
df.Course_B > 50
# Out:
# A     True
# B    False
# C     True
# D     True
# Name: Course_B, dtype: bool

# %%
filter_index = df.Course_B > 50

# %%
df[filter_index]
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# C        95        98        59
# D        60        75        60

# %%
print(filter_index)
# Out:
# A     True
# B    False
# C     True
# D     True
# Name: Course_B, dtype: bool

# %%
df.loc[[True,False,True,True],[True,True,True]]
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# C        95        98        59
# D        60        75        60

# %%
df[(df.Course_A > 50) & (df.Course_B < 50)]
# Out:
#    Course_A  Course_B  Course_C
# B        90        34        80

# %%
df[(df.Course_A < 50)|(df.Course_B < 50)|(df.Course_C < 50)]
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# B        90        34        80

# %%
df[(df.Course_A >= 50)&(df.Course_B >= 50)&(df.Course_C >= 50)]
# Out:
#    Course_A  Course_B  Course_C
# C        95        98        59
# D        60        75        60

# %%
(df.Course_A >= 50)&(df.Course_B >= 50)&(df.Course_C >= 50)
# Out:
# A    False
# B    False
# C     True
# D     True
# dtype: bool

# %%
df.Course_B.apply(lambda x : x > 50)
# Out:
# A     True
# B    False
# C     True
# D     True
# Name: Course_B, dtype: bool

# %%
df[df.Course_B.apply(lambda x : x > 50)]
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# C        95        98        59
# D        60        75        60

# %%
df.apply(lambda x : pd.Series([x[0]/2,x[1]*2,x[2]],index=["Double_Course_A","Half_Course_B","Course_C"]),axis=1)
# Out:
#    Double_Course_A  Half_Course_B  Course_C
# A             30.0          130.0      35.0
# B             45.0           68.0      80.0
# C             47.5          196.0      59.0
# D             30.0          150.0      60.0

# %%
# finding NA values

# %%
df.isna()
# Out:
#    Course_A  Course_B  Course_C
# A     False     False     False
# B     False     False     False
# C     False     False     False
# D     False     False     False

# %%
housing_df.isna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
df
# Out:
#    Course_A  Course_B  Course_C
# A        60        65        35
# B        90        34        80
# C        95        98        59
# D        60        75        60

# %%
df.sum() # compute the columns
# Out:
# Course_A    305
# Course_B    272
# Course_C    234
# dtype: int64

# %%
df.isna().sum()
# Out:
# Course_A    0
# Course_B    0
# Course_C    0
# dtype: int64

# %%
housing_df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
housing_df.total_bedrooms.isna().sum() # apply a function over one column
# Out:
# 207

# %%
housing_df[housing_df.total_bedrooms.isna()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
housing_df.total_bedrooms.isna().sum()/len(housing_df) * 100 # percentage of NA
# Out:
# 1.002906976744186

# %%
# filtered_housing_df = housing_df.dropna()

# %%
filtered_housing_df = housing_df[~housing_df.total_bedrooms.isna()] # ~ means the opposite

# %%
filtered_housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# housing_df.dropna(axis = 0 or axis = 1) 0 drop the rows with NA, 1 drop the column with NA

# %%
housing_df[housing_df.total_bedrooms > 1000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 95       -122.26     37.80                36.0       5329.0          2477.0
# 96       -122.26     37.82                31.0       4596.0          1331.0
# 98       -122.26     37.82                22.0       3682.0          1270.0
# 99       -122.26     37.82                37.0       3633.0          1085.0
# ...          ...       ...                 ...          ...             ...
# 20544    -121.76     38.55                23.0       8800.0          1857.0
# 20563    -121.75     38.67                 9.0      12139.0          2640.0
# 20567    -121.79     38.66                15.0       6809.0          1052.0
# 20603    -121.54     39.13                18.0       4289.0          1021.0
# 20629    -121.39     39.12                28.0      10035.0          1856.0
#
# ...

# %%
filtered_housing_df.ocean_proximity.count()
# Out:
# 20433

# %%
filtered_housing_df.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
filtered_housing_df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
set(filtered_housing_df.ocean_proximity)
# Out:
# {'<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'}

# %% [raw]
# # in housing_df, change the text value in the column "ocean_proximity" to numeric values as below

# %%
replace_value = {
    'NEAR BAY':0, 
    '<1H OCEAN':10, 
    'INLAND':100, 
    'NEAR OCEAN':5, 
    'ISLAND':-1
}

# %%
housing_df.loc[:," Replace_Method_1"] = housing_df.ocean_proximity.apply(lambda x : replace_value[x])

# %%
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing_df[housing_df.population < 5000].population.mean()
# Out:
# 1339.7772805507745

# %%
housing_df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', ' Replace_Method_1'],
#       dtype='object')

# %%
housing_df.groupby(["ocean_proximity"]).agg({
    'longitude':'mean',
    'latitude' : 'mean',
    'population': 'sum'
}).sort_values(by='population')
# Out:
#                   longitude   latitude  population
# ocean_proximity
# ISLAND          -118.354000  33.358000      3340.0
# NEAR BAY        -122.260694  37.801057   2817427.0
# NEAR OCEAN      -119.332555  34.738439   3598955.0
# INLAND          -119.732990  36.731829   9112744.0
# <1H OCEAN       -118.847766  34.560577  13889374.0
